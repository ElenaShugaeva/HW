# %%
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd

# %%
KEYWORDS = ['пайтон', 'парсинг']
params = {
    'text': ['python', 'парсинг']
}
url = 'https://habr.com/ru/all/'
req = requests.get(url, params)
# time.sleep(0.3)
soup = BeautifulSoup(req.text, 'html.parser')
posts = soup.find_all('article', class_='post')
sheets = pd.DataFrame()
for post in posts:
    time = post.find_all('span', class_='post__time')
    for tm in time:
        req_time = tm.text
    link = post.find_all('a', class_='post__title_link')
    for lin in link:
        req_link = lin.attrs.get('href')
    header = post.find_all('h2', class_='post__title')
    for hd in header:
        req_header = hd.text
    row = {'time': req_time, 'link': req_link, 'header': req_header}
    sheets = pd.concat([sheets, pd.DataFrame([row])])
sheets
# Out:
#               time                                               link  \
# 0  сегодня в 19:59                   https://habr.com/ru/post/533356/
# 0  сегодня в 19:43   https://habr.com/ru/company/dataart/blog/533450/
# 0  сегодня в 19:17    https://habr.com/ru/company/itelma/blog/533444/
# 0  сегодня в 18:49  https://habr.com/ru/company/madrobots/blog/533...
# 0  сегодня в 18:48                   https://habr.com/ru/post/533428/
# 0  сегодня в 18:40  https://habr.com/ru/company/nanosoft/blog/528300/
# 0  сегодня в 18:30      https://habr.com/ru/company/otus/blog/533416/
# 0  сегодня в 18:25      https://habr.com/ru/company/otus/blog/533400/
# 0  сегодня в 18:14  https://habr.com/ru/company/cardsmobile/blog/5...
# 0  сегодня в 17:46  https://habr.com/ru/company/selectel/blog/533412/
# 0  сегодня в 17:27                   https://habr.com/ru/post/533344/
# 0  сегодня в 17:26                   https://habr.com/ru/post/533418/
# 0  сегодня в 17:17  https://habr.com/ru/company/skillfactory/blog/...
# 0  сегодня в 17:12  https://habr.com/ru/company/etmc_exponenta/blo...
# 0  сегодня в 17:10  https://habr.com/ru/company/JetBrains/blog/533...
# 0  сегодня в 17:04     https://habr.com/ru/company/badoo/blog/533382/
# 0  сегодня в 16:46                   https://habr.com/ru/post/533406/
# 0  сегодня в 16:33    https://habr.com/ru/company/skyeng/blog/532146/
# 0  сегодня в 16:30                   https://habr.com/ru/post/533402/
# 0  сегодня в 16:20   https://habr.com/ru/company/itsumma/blog/533394/
#
#                                               header
# 0  \nИзучаем RISC-V с нуля, часть 2: прерыванияи ...
# 0  \nЭдуард Казарян: «Больше народу наградили тол...
# 0  \nКак обстоят дела с обновлениями софта по воз...
# 0  \nПрощай, 2020! В новый год — с робокрабом, ед...
# 0  \nКак кандидату (разработчику) и HR с Team lea...
# 0  \nАнализ целостности сигналов в PADS Professio...
# 0  \nТестирование инфраструктуры как кода Terrafo...
# 0  \n10 примеров эффективного общения для тестиро...
# 0  \nКак мы автоматизировали выгрузки и другие Ad...
# 0  \nКаждому нужен кто-то: обнаружена зона головн...
# 0                 \nБезопасность веб: из LFI в RCE\n
# 0           \nТемно-серая зона экосистемы Telegram\n
# 0  \n9 тяжелых уроков, которые я усвоил за 18 лет...
# 0  \nКак устроена силовая установка пассажирского...
# 0  \nBig Data Tools EAP 12: экспериментальная под...
# 0  \nБыстро и гибко настраиваем  наблюдаемость с ...
# 0  \nВосстановление устройства Huawei AR1200 свои...
# 0  \nЗанятное мини-интервью с основными контрибью...
# 0   \nУсилитель звукового сигнала мощностью 600 Вт\n
# 0  \nНовый инструмент для Повелителей Хаоса: AWS ...

# %%
import json
url = url = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'
payload = {'emailAddresses': ['xxx@x.ru', 'yyy@y.com']}
headers = {'Server': 'nginx', 'Connection': 'keep-alive', 'Vaar-Version': '0', 'Vaar-Header-App-Product': 'hackcheck-web-avast'}
requs = requests.post(url, data= json.dumps(payload), headers = headers )

# %%
pd.DataFrame(requs.json()['breaches'])
# Out:
#                                                           16613  \
# breachId                                                  16613
# site                                           verifications.io
# recordsCount                                          677914246
# description   Big data e-mail verification platform verifica...
# publishDate                                2019-03-28T00:00:00Z
# statistics    {'usernames': 0, 'passwords': 0, 'emails': 677...
#
#                                                           17609  \
# breachId                                                  17609
# site                                                     vk.com
# recordsCount                                           42536910
# description   At some time in 2020, the Russian social netwo...
# publishDate                                2020-05-21T00:00:00Z
# statistics    {'usernames': 0, 'passwords': 0, 'emails': 205...
#
#                                                           17110  \
# breachId                                                  17110
# site                                              azcentral.com
# recordsCount                                             705538
# description   At an unconfirmed date, online Arizona newspap...
# publishDate                                2020-01-03T00:00:00Z
# statistics    {'usernames': 0, 'passwords': 702971, 'emails'...
#
#                                                           17670  \
# breachId                                                  17670
# site                                                wishbone.io
# recordsCount                                           37475476
# description   In January 2020, the online poll website Wishb...
# publishDate                                2020-05-28T00:00:00Z
# statistics    {'usernames': 31111127, 'passwords': 10648734,...
#
#                                                           13094  \
# breachId                                                  13094
# site                                             myheritage.com
# recordsCount                                          110041653
# description   In October 2017, a customer database belonging...
# publishDate                                2017-11-04T00:00:00Z
# statistics    {'usernames': 0, 'passwords': 110041647, 'emai...
#
#                                                           16768  \
# breachId                                                  16768
# site                                                  canva.com
# recordsCount                                          137434010
# description   In May 2019, graphic-design site Canva's datab...
# publishDate                                2019-06-13T00:00:00Z
# statistics    {'usernames': 137304104, 'passwords': 61348974...
#
#                                                            3176  \
# breachId                                                   3176
# site                                             parapa.mail.ru
# recordsCount                                            5029003
# description   In July and August 2016, two criminals execute...
# publishDate                                2017-02-14T00:00:00Z
# statistics    {'usernames': 5029000, 'passwords': 5029003, '...
#
#                                                              41  \
# breachId                                                     41
# site                                                dropbox.com
# recordsCount                                           68591031
# description   Cloud storage company Dropbox suffered a major...
# publishDate                                2016-10-24T00:00:00Z
# statistics    {'usernames': 0, 'passwords': 68591031, 'email...
#
#                                                               2  \
# breachId                                                      2
# site                                               linkedin.com
# recordsCount                                          158591429
# description   In 2012, online professional networking platfo...
# publishDate                                2016-10-21T00:00:00Z
# statistics    {'usernames': 0, 'passwords': 111975337, 'emai...
#
#                                                            3587  \
# breachId                                                   3587
# site                                               rayli.com.cn
# recordsCount                                            4844179
# description   On an unconfirmed date, Chinese gossip site Ra...
# publishDate                                2017-03-01T00:00:00Z
# statistics    {'usernames': 4841886, 'passwords': 4833694, '...
#
#                                                           17009  \
# breachId                                                  17009
# site                                                  zynga.com
# recordsCount                                          216159495
# description   In September 2019, the game developer Zynga wa...
# publishDate                                2019-10-17T00:00:00Z
# statistics    {'usernames': 214648143, 'passwords': 13476279...
#
#                                                              12  \
# breachId                                                     12
# site                                                     vk.com
# recordsCount                                           91262655
# description   Popular Russian social networking platform VKo...
# publishDate                                2016-10-29T00:00:00Z
# statistics    {'usernames': 0, 'passwords': 89691243, 'email...
#
#                                                               3  \
# breachId                                                      3
# site                                                  adobe.com
# recordsCount                                          152046506
# description   In October of 2013, criminals penetrated Adobe...
# publishDate                                2016-10-21T00:00:00Z
# statistics    {'usernames': 0, 'passwords': 129430596, 'emai...
#
#                                                           13662  \
# breachId                                                  13662
# site                                                 netlog.com
# recordsCount                                           52904632
# description   Netlog (formerly known as Facebox and Bingbox)...
# publishDate                                2018-02-18T00:00:00Z
# statistics    {'usernames': 0, 'passwords': 52902665, 'email...
#
#                                                            3520  \
# breachId                                                   3520
# site                                             globalreach.eu
# recordsCount                                             921298
# description   In 2016, Global Reach Technology's database wa...
# publishDate                                2017-03-15T00:00:00Z
# statistics    {'usernames': 13492, 'passwords': 921298, 'ema...
#
#                                                            3164  \
# breachId                                                   3164
# site                                              cfire.mail.ru
# recordsCount                                           12880232
# description   In July and August of 2016, two criminals carr...
# publishDate                                2017-02-14T00:00:00Z
# statistics    {'usernames': 12880232, 'passwords': 12880222,...
#
#                                                            2961  \
# breachId                                                   2961
# site                                           cdprojektred.com
# recordsCount                                            1871459
# description   In March 2016, CDProjektRed.com.com's forum da...
# publishDate                                2017-01-31T00:00:00Z
# statistics    {'usernames': 1871410, 'passwords': 1871457, '...
#
#                                                              15  \
# breachId                                                     15
# site                                                  imesh.com
# recordsCount                                           50913222
# description   In June 2016, a cache of over 51 million user ...
# publishDate                                2016-10-23T00:00:00Z
# statistics    {'usernames': 50909015, 'passwords': 50913222,...
#
#                                                            3669
# breachId                                                   3669
# site                                                  youku.com
# recordsCount                                           94244880
# description   Youku is a large Chinese video content company...
# publishDate                                2017-03-24T00:00:00Z
# statistics    {'usernames': 0, 'passwords': 94238535, 'email...
